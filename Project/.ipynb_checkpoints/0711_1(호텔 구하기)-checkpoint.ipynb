# %%
import pandas as pd

# %%
df = pd.read_csv('Hotel_Reviews.csv')
df
# Out:
#                                             Hotel_Address  \
# 0        s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 1        s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 2        s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 3        s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 4        s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# ...                                                   ...
# 515733  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515734  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515735  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515736  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515737  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
#
#         Additional_Number_of_Scoring Review_Date  Average_Score  \
# 0                                194    8/3/2017            7.7
# 1                                194    8/3/2017            7.7
# 2                                194   7/31/2017            7.7
# ...

# %%
df.describe()
# Out:
#        Additional_Number_of_Scoring  Average_Score  \
# count                 515738.000000  515738.000000
# mean                     498.081836       8.397487
# std                      500.538467       0.548048
# min                        1.000000       5.200000
# 25%                      169.000000       8.100000
# 50%                      341.000000       8.400000
# 75%                      660.000000       8.800000
# max                     2682.000000       9.800000
#
#        Review_Total_Negative_Word_Counts  Total_Number_of_Reviews  \
# count                      515738.000000            515738.000000
# mean                           18.539450              2743.743944
# std                            29.690831              2317.464868
# min                             0.000000                43.000000
# 25%                             2.000000              1161.000000
# 50%                             9.000000              2134.000000
# ...

# %%
hotel = df[['Hotel_Name','Review_Date','Reviewer_Nationality','Total_Number_of_Reviews','Negative_Review','Review_Total_Negative_Word_Counts','Positive_Review','Review_Total_Positive_Word_Counts','Total_Number_of_Reviews_Reviewer_Has_Given','Reviewer_Score','Average_Score','Tags']]
hotel
# Out:
#                    Hotel_Name Review_Date Reviewer_Nationality  \
# 0                 Hotel Arena    8/3/2017              Russia
# 1                 Hotel Arena    8/3/2017             Ireland
# 2                 Hotel Arena   7/31/2017           Australia
# 3                 Hotel Arena   7/31/2017      United Kingdom
# 4                 Hotel Arena   7/24/2017         New Zealand
# ...                       ...         ...                  ...
# 515733  Atlantis Hotel Vienna   8/30/2015              Kuwait
# 515734  Atlantis Hotel Vienna   8/22/2015             Estonia
# 515735  Atlantis Hotel Vienna   8/19/2015               Egypt
# 515736  Atlantis Hotel Vienna   8/17/2015              Mexico
# 515737  Atlantis Hotel Vienna    8/9/2015             Hungary
#
#         Total_Number_of_Reviews  \
# 0                          1403
# 1                          1403
# 2                          1403
# 3                          1403
# 4                          1403
# ...

# %%
# var = hotel.loc[df['Total_Number_of_Reviews']>=1000]
var = hotel.drop_duplicates(['Hotel_Name'])
var.index
# Out:
# Int64Index([     0,    405,    971,   2008,   3778,   3813,   3832,   5257,
#               7480,   7616,
#             ...
#             509019, 509232, 510808, 511319, 511920, 511962, 512401, 512545,
#             512645, 515413],
#            dtype='int64', length=1492)

# %%
type(var)
# Out:
# pandas.core.frame.DataFrame

# %%
var
# Out:
#                               Hotel_Name Review_Date Reviewer_Nationality  \
# 0                            Hotel Arena    8/3/2017              Russia
# 405                     K K Hotel George    8/3/2017             Ireland
# 971              Apex Temple Court Hotel    8/2/2017      United Kingdom
# 2008    The Park Grand London Paddington    8/2/2017              Cyprus
# 3778                 Monhotel Lounge SPA   6/29/2017              Brazil
# ...                                  ...         ...                  ...
# 511962        Suite Hotel 900 m zur Oper    8/2/2017             Germany
# 512401                     Hotel Amadeus   6/26/2017            Thailand
# 512545                      The Berkeley    7/8/2017      United Kingdom
# 512645     Holiday Inn London Kensington    8/3/2017      United Kingdom
# 515413             Atlantis Hotel Vienna    8/2/2017      United Kingdom
#
#         Total_Number_of_Reviews  \
# 0                          1403
# ...

# %%
temp = var.index

# %%
type(temp)
# Out:
# pandas.core.indexes.numeric.Int64Index

# %%
temp = list(temp)

# %%
temp
# Out:
# [0,
#  405,
#  971,
#  2008,
#  3778,
#  3813,
#  3832,
#  5257,
#  7480,
#  7616,
#  7743,
#  7961,
#  8121,
#  8301,
#  11259,
#  11345,
#  12352,
#  12608,
#  12697,
#  12921,
#  13100,
#  13182,
#  13290,
#  13425,
#  14708,
#  14829,
#  17380,
#  17549,
#  17720,
#  17806,
#  17852,
#  17922,
#  18095,
#  18236,
#  18396,
#  18445,
#  18936,
#  20090,
#  20472,
#  20546,
#  21147,
#  21536,
#  21748,
#  21814,
#  21843,
#  21919,
#  22010,
#  22035,
#  22155,
#  22189,
#  22226,
#  22321,
#  22434,
#  22525,
#  22607,
#  22874,
#  23036,
#  24278,
#  24583,
#  25592,
#  26106,
#  26350,
#  27867,
#  28142,
#  28314,
#  28329,
#  28757,
#  29619,
#  30211,
#  30320,
#  30653,
#  31647,
#  32137,
#  32668,
#  33131,
#  33526,
#  33659,
#  33703,
#  33862,
#  33939,
#  33963,
#  34078,
#  34311,
#  34383,
#  34604,
#  34660,
#  35372,
#  35442,
#  35804,
#  36043,
#  36127,
#  36359,
#  36646,
#  36835,
#  37337,
#  37377,
#  37445,
#  37532,
#  37733,
#  37858,
#  38139,
# ...

# %%
for i in range(len(temp)-1):
    temp[i] = temp[i+1] - temp[i]

# %%
del temp[len(temp)-1]

# %%
# 가장 많이 나온 호텔
max(temp)
# Out:
# 4789

# %%
temp[186]
# Out:
# 4789

# %%
var['Hotel_Name'][0]
# Out:
# 'Hotel Arena'

# %%
names = []

# %%
len(df)
# Out:
# 515738

# %%
names = []
for i in range(len(df)):
    try:
        names.append(var['Hotel_Name'][i])
    except:
        pass

# %%
names
# Out:
# ['Hotel Arena',
#  'K K Hotel George',
#  'Apex Temple Court Hotel',
#  'The Park Grand London Paddington',
#  'Monhotel Lounge SPA',
#  'Kube Hotel Ice Bar',
#  'The Principal London',
#  'Park Plaza County Hall London',
#  'One Aldwych',
#  'Splendid Etoile',
#  'Hotel Trianon Rive Gauche',
#  'InterContinental London Park Lane',
#  'Novotel Suites Paris Nord 18 me',
#  'Grand Royale London Hyde Park',
#  'Milestone Hotel Kensington',
#  'Crowne Plaza London Kings Cross',
#  'Select Hotel',
#  'H tel De Vend me',
#  'Pullman Paris Centre Bercy',
#  'Gardette Park Hotel',
#  'Hotel Panache',
#  'H tel des Ducs D Anjou',
#  'Hotel Scribe Paris Opera by Sofitel',
#  'Novotel London West',
#  'Haymarket Hotel',
#  'Intercontinental London The O2',
#  'H tel Juliana Paris',
#  'Hotel L Antoine',
#  'Belfast',
#  'Shangri La Hotel Paris',
#  'Mercure Paris Tour Eiffel Pont Mirabeau',
#  'Knightsbridge Hotel',
#  'The London EDITION',
#  'The Cranley Hotel',
#  'Hotel Le 10 BIS',
# ...

# %%
len(names)
# Out:
# 1492

# %%
len(var)
# Out:
# 1492

# %%
names[186]
# Out:
# 'Britannia International Hotel Canary Wharf'

# %%
names[485]
# Out:
# 'Hotel Claridge Paris'

# %%
names[1476]
# Out:
# 'Crowne Plaza London Ealing'

# %%
hotel.loc[hotel['Hotel_Name']=='Britannia International Hotel Canary Wharf']
# Out:
#                                        Hotel_Name Review_Date  \
# 63942  Britannia International Hotel Canary Wharf    8/3/2017
# 63943  Britannia International Hotel Canary Wharf    8/3/2017
# 63944  Britannia International Hotel Canary Wharf    8/2/2017
# 63945  Britannia International Hotel Canary Wharf    8/2/2017
# 63946  Britannia International Hotel Canary Wharf    8/2/2017
# ...                                           ...         ...
# 68726  Britannia International Hotel Canary Wharf    8/4/2015
# 68727  Britannia International Hotel Canary Wharf    8/4/2015
# 68728  Britannia International Hotel Canary Wharf    8/4/2015
# 68729  Britannia International Hotel Canary Wharf    8/4/2015
# 68730  Britannia International Hotel Canary Wharf    8/4/2015
#
#       Reviewer_Nationality  Total_Number_of_Reviews  \
# 63942      United Kingdom                      9086
# 63943      United Kingdom                      9086
# 63944      United Kingdom                      9086
# ...
