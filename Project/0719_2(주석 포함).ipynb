# %%
import pandas as pd
import matplotlib.pyplot as plt

import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
from nltk.tokenize import RegexpTokenizer
from nltk import Text
from nltk import FreqDist
from nltk.tag import pos_tag
from nltk.tokenize import word_tokenize

#nltk.download('stopwords')

# %%
def preprocessing(text):
    #토큰화
    tokens = [word for sent in nltk.sent_tokenize(text)
              for word in nltk.word_tokenize(sent)]
    print('token word')
    #print(tokens)
    print()
    
    #불용어 제거
    stop=stopwords.words('english')
    tokens=[token for token in tokens if token not in stop]
    print('remove stopwords')
    #print(tokens)
    print()
    
    #소문자화
    tokens=[word.lower() for word in tokens]
    print('lower capitalization')
    #print(tokens)
    print()
    
    #표제어 추출
    lmtzr = WordNetLemmatizer()
    tokens = [lmtzr.lemmatize(word) for word in tokens]
    print( 'lemmatization')
    #print( tokens )
    print()
    
    tokens = [lmtzr.lemmatize(word, 'v') for word in tokens]
    print('lemmatization/verb' )
    #print( tokens )
    print()
    
    #어간추출
#     stemmer = PorterStemmer()
#     tokens = [ stemmer.stem(word) for word in tokens ]
#     print( 'stemming' )
#     print(tokens)
#     print()
    
    preprocessed_text= ' '.join(tokens)
    return preprocessed_text

# %%
# data =
# preprocessed = preprocessing(data)
# print(preprocessed)

# %%
testdata=pd.read_csv('Hotel_Test.csv')
testdata
# Out:
#       Average_Score                                    Negative_Review  \
# 0               7.1   The car park was small and unpleasant People ...
# 1               7.1   We weren t told that the only spa facility op...
# 2               7.1   I asked how far the O2 was and got told a 7 m...
# 3               7.1   Hot stuffy room air con not working properly ...
# 4               7.1   Although the price seems like it is cheap you...
# ...             ...                                                ...
# 4784            7.1   Long wait for check in arrived at 6 30pm and ...
# 4785            7.1                          concierge was uninformed
# 4786            7.1                                I had no complaints
# 4787            7.1   Really shabby and run down hotel Needs a tota...
# 4788            7.1   Stains on the carpet peeling wallpaper scruff...
#
#                                         Positive_Review  Reviewer_Score
# 0      The location was excellent for getting to the O2             7.9
# 1      The house keeping lady made my boyfriends day...             8.3
# 2                                           No Positive             6.3
# 3                                       The bed was OK              5.4
# 4      The Receptionists and Cleaners are very polit...             6.3
# ...                                                 ...             ...
# 4784                                        No Positive             6.3
# 4785                               good value for money             7.9
# 4786                        Good location easy to park              8.3
# 4787   Location was great staff pretty good and it w...             5.4
# 4788                                            Nothing             3.8
#
# [4789 rows x 4 columns]

# %%
neg_rev=' '
pos_rev=' '
for i in range(len(testdata.index)):
    neg_rev=neg_rev+testdata['Negative_Review'][i]
    pos_rev=pos_rev+testdata['Positive_Review'][i]

# %%
neg_proccessed=preprocessing(neg_rev)
pos_proccessed=preprocessing(pos_rev)
# Out:
# token word
#
# remove stopwords
#
# lower capitalization
#
# lemmatization
#
# lemmatization/verb
#
# token word
#
# remove stopwords
#
# lower capitalization
#
# lemmatization
#
# lemmatization/verb

# %%
neg_proccessed
# Out:
# 'the car park small unpleasant people mercedes bmws take 2 space we lucky get space drive around 10 time we tell spa facility open pool sauna already pay find enter spa area i ask far o2 get tell 7 minute walk way 2 train away i happy ok hot stuffy room air con work properly filthy window wallpaper rip wear bedside furniture tatty carpet wear damage bathroom door latch wear make door difficult open inside shower another era control bath tap poor shower curtain result wet floor carpet corridor wear tatty nasty musty aroma area all place around ten year overdue complete renovation although price seem like cheap pay extra everything like swim pool wifi fool sometimes come others extra like breakfast the hotel see better day include stairwell carpet quite threadbare the common part need decoration the quality towel bathroom good one set toiletry two people there item drug paraphernalia hall construction go around hotel many path close have pay extra use hotel pool spa health hazard stair lead change room pool filthy pool tile look like ever clean wood rot sauna floor food hair outside the shower outside sauna hot cold button press time order scald freeze pasta pizzaria microwave staff incredibly rude area hotel one point aunt ask repeat understand the wifi incredibly slow power point lack date like decor whole hotel the part review i give sad face location i even give hotel 2 room far hot air condition work happen previous stay staff member open window screwdriver unfortunately huge vent outside really noisy window open hardly sleep night the guy serve u professional tell u customer situation want get room the car park small park my car stick two car tell u first come first serve wa happy the build site next door dirty window spoil lovely view see photo access little tricky due local construction work area adversely impact journey time cause noise issue inside hotel no negative the staff welcome i would go far say jade unhappy obe point see argue customer front customer the double bed i select double bed two single bed zip together poorly uncomfortably so cheap such bad sleep there mouse scurry around property full view customer main lobby near din bar area inside room i saw mouse two occasion stay the room much wear tear wall visibly stain mark damage toilet show mould shower totally careless i ask non smoke room room i get reek smoke everywhere curtain toilet so bad i want full refund the lift badly adjust dangerous gap lead edge og car door park horrible the park garage narrow drive noticng full near entrance garage 3 member staff walk around inform anyone at least 4 car behind u drive back then i walk ask else could park area tell check side street park then drive around find park resident after 30 minute park westferry circus garage 10 minute walk away since garage mention maximum duration park on hotel furnish little outdated the carpet stair instance quite wear wifi work there card room detail network could find either phone the room nice clean beware shower water pressure good screen front bath fairly small twist shower head wall inch whole bathroom get wet the head fix wall people approx 1 85 able stand without squat little if i would pay full price hotel frankly i would disappoint compare 3 4 star hotel london i visit hotel 3 4 star base room comfort staff park every part stay horrendous from start finish when arrive socket work could charge phone head dinner the room dirty i wake morning bathroom flood water come way room wet bag shoe toiletry bag etc could get reception phone age nobody come clean mess could get hold gm breakfast awful dry toast could stomach eat place dirty needle say process look full refund hotel nothing bathroom could better standard everything bathroom work perfectly fine the phone work room the steam room action they sheff make sandwich day menu body massage spa and i mention concern staff management seem bother issue or give solution all round i think management staff need listen guest you offer ...

# %%
pos_proccessed
# Out:
# 'the location excellent get o2 the house keep lady make boyfriend day funny wasno positive the bed ok the receptionist cleaner polite friendly hard work staff we enjoy stay would come room clean enough amenity one could request anytime without problem my daughter i upgrade free charge executive room balcony water we enjoy quality price spice restaurant i delight find porridge breakfast jenny restaurant the electric fan welcome addition room could control room temperature ac quite easily short walk tube station although construction close many path staff friendly location good the bed nice could smoke room bouns i love layout hotel room overlook thames good bed room breakfast substantial well prepare location perfect need excellent value money friendly staff lot amenity broad range din option spa downstairs stone throw canary wharf have already recommend family friend last minute work stopover short break case need stay part london location good near train station bedroom big book room without window hotel give u big room window without charge just convenience great location spacious room whole place look bite tire the room perfectly fine nothing specifically stand we luck find good deal via book com location convenient it 10 minute walk canary wharf station take either underground dl better even water bus get crowd air stifle if rush enjoy see sight thames one best way travel city nothing we like everything hotel please still smoke room good partner leave go outside smoke morning able enjoy leisurely first coffee relax able cigarette this second trip hotel definitely back i love asian theme class hotel it car park we offer free upgrade room hotel pretty empty staff friendly the view excellent great time barman really great no positive the hotel general absolutely fine 2 night stay ac make noise put 2 either 1 3 even 3 temp 17 5 still warm short staff que check expensive wifi 30 min free location isolate way 1 9 mile o2 arena unless go swim wrong info old hotel would require serious refurbishment room tidy since price low london okay look stylish waa clean need little refurbisging couls see carpet get old bathroom corner look mankie bath plug dont work properly nice small fridge put drink location good bed comfortable decent facility i stay hotel 15 year unfortunately price often far high i several august september visit london your price le 100 but far higher i like hotel price the bed comfy view ok work carry nearby didnt hear 9ish very good travel canary wharf tube 5 min walk away the window view wonderful i like hotel interior design great location redeem feature close canary wharf you find lot shop mall close dlr underground staff friendly i guess price rather cheap consider location surrouding area the room spacious window across room make light airy welcome the bathroom modern mirror everywhere make even spacious the bed comfy armchair also the room clean well maintain the location hotel fabulous great value money consider area canary wharf the room also cosy old fashion consider exterior make feel homely inside the receptionist due fault book upgrade bigger room i think nice friendly even though i best mood the room also great dress room table load space great mirror make look half decent fab good location short walk shop restaurant public transport canary wharf the room spacious comfortable staff helpful find room u ready we stay one night leave early next day use facility big hotel lot facility good location order visit london daysno positive room cleanliness good convince transport restaurant location aesthetic location to frank nothing wow hotel the entrance good enter via filthy door busy unwelcoming reception no positive location fitness facility not lot honest it average hotel london i would stay the public area hotel ok the room quiet it relatively affordable not worth price there nothing i think like property location good easy find close tube station we book room without window surprise arrival room allocate l ...

# %%
type(pos_proccessed)
# Out:
# str

# %%
# pos_proccessed = pos_proccessed.split()

# %%
# pos_proccessed의 단어별 빈도수 시각화(20개)
retokenize = RegexpTokenizer("[\w]+")
retokenize.tokenize(pos_proccessed)
text=Text(retokenize.tokenize(pos_proccessed))
text.plot(20)

# %%
# neg_proccessed의 단어별 빈도수 시각화(20개)

retokenize = RegexpTokenizer("[\w]+")
retokenize.tokenize(pos_proccessed)
text=Text(retokenize.tokenize(neg_proccessed))
text.plot(20)

# %%
# 긍정어사전, 부정어 사전 로드
pos = open('./positive-words.txt')
neg = open('./negative-words.txt')

# %%
# 긍정, 부정어 사전의 단어를 list에 저장
pos_temp = []
neg_temp = []
while True:
    line = pos.readline()
    line = line.replace('\n', '')
    pos_temp.append(line)
    if not line: break
pos.close()

while True:
    line = neg.readline()
    line = line.replace('\n', '')
    neg_temp.append(line)
    if not line: break
neg.close()

# %%
# 품사찾기
tagged_list_pos = pos_tag(word_tokenize(pos_proccessed))
tagged_list_neg = pos_tag(word_tokenize(neg_proccessed))

# %%
# 명사, 부사, 형용사만 따로 리스트에 저장

filtered_list_pos = []
filtered_list_neg = []

include_list = ['NN', 'NNS', 'RBS', 'RBR', 'RB', 'JJS', 'JJR', 'JJ']
for t in tagged_list_pos :
    if t[1] in include_list:
        filtered_list_pos.append(t[0])
filtered_list_pos

for t in tagged_list_neg :
    if t[1] in include_list:
        filtered_list_neg.append(t[0])
filtered_list_neg
# Out:
# ['car',
#  'park',
#  'small',
#  'unpleasant',
#  'people',
#  'bmws',
#  'space',
#  'space',
#  'drive',
#  'time',
#  'spa',
#  'facility',
#  'open',
#  'pool',
#  'sauna',
#  'already',
#  'enter',
#  'spa',
#  'area',
#  'i',
#  'far',
#  'o2',
#  'tell',
#  'minute',
#  'walk',
#  'way',
#  'train',
#  'away',
#  'i',
#  'happy',
#  'ok',
#  'hot',
#  'stuffy',
#  'room',
#  'air',
#  'con',
#  'work',
#  'properly',
#  'filthy',
#  'window',
#  'wallpaper',
#  'rip',
#  'wear',
#  'bedside',
#  'furniture',
#  'tatty',
#  'carpet',
#  'wear',
#  'damage',
#  'bathroom',
#  'door',
#  'latch',
#  'door',
#  'difficult',
#  'open',
#  'shower',
#  'era',
#  'control',
#  'bath',
#  'tap',
#  'poor',
#  'shower',
#  'curtain',
#  'result',
#  'wet',
#  'floor',
#  'carpet',
#  'corridor',
#  'tatty',
#  'nasty',
#  'musty',
#  'aroma',
#  'area',
#  'place',
#  'around',
#  'year',
#  'overdue',
#  'complete',
#  'renovation',
#  'price',
#  'cheap',
#  'pay',
#  'everything',
#  'swim',
#  'pool',
#  'wifi',
#  'fool',
#  'sometimes',
#  'come',
#  'others',
#  'breakfast',
#  'hotel',
#  'better',
#  'day',
#  'stairwell',
#  'carpet',
#  'quite',
#  'common',
#  'part',
#  'decoration',
#  'quality',
#  'towel',
#  'bathroom',
#  'good',
#  'toiletry',
#  'people',
#  'there',
#  'item',
#  'drug',
#  'paraphernalia',
#  'construction',
#  'hotel',
#  'many',
#  'close',
#  'pay',
#  'extra',
#  'use',
#  'hotel',
#  'pool',
#  'health',
#  'hazard',
#  'stair',
#  'lead',
#  'change',
#  'room',
#  'pool',
#  'filthy',
#  'pool',
#  'tile',
#  'look',
#  'ever',
#  'clean',
#  'wood',
#  'rot',
#  'sauna',
#  'floor',
#  'food',
#  'hair',
#  'shower',
#  'sauna',
#  'hot',
#  'cold',
#  'button',
#  'press',
#  'time',
#  'order',
#  'scald',
#  'freeze',
#  'pasta',
#  'pizzaria',
#  'staff',
#  'incredibly',
#  'rude',
#  'area',
#  'hotel',
#  'point',
#  'aunt',
#  'repeat',
#  'wifi',
#  'incredibly',
#  'slow',
#  'power',
#  'point',
#  'lack',
#  'date',
#  'decor',
#  'whole',
#  'hotel',
#  'part',
#  'review',
#  'sad',
#  'face',
#  'location',
#  'even',
#  'give',
#  'hotel',
#  'room',
#  'far',
#  'hot',
#  'air',
#  'condition',
#  'work',
#  'happen',
#  'previous',
#  'stay',
#  'staff',
#  'member',
#  'open',
#  'window',
#  'screwdriver',
#  'unfortunately',
#  'huge',
#  'vent',
#  'really',
#  'noisy',
#  'window',
#  'open',
#  'hardly',
#  'sleep',
#  'night',
#  'guy',
#  'u',
#  'professional',
#  'tell',
#  'u',
#  'customer',
#  'situation',
#  'get',
#  'room',
#  'car',
#  'park',
#  'small',
#  'park',
#  'car',
#  'stick',
#  'car',
#  'tell',
#  'first',
#  'first',
#  'wa',
#  'happy',
#  'build',
#  'site',
#  'next',
#  'door',
#  'dirty',
#  'window',
#  'spoil',
#  'lovely',
#  'view',
#  'photo',
#  'access',
#  'little',
#  'tricky',
#  'due',
#  'local',
#  'construction',
#  'work',
#  'area',
#  'adversely',
#  'impact',
#  'journey',
#  'time',
#  'cause',
#  'noise',
#  'issue',
#  'hotel',
#  'negative',
#  'staff',
#  'welcome',
#  'i',
#  'far',
#  'jade',
#  'unhappy',
#  'obe',
#  'point',
#  'argue',
#  'customer',
#  'front',
#  'customer',
#  'double',
#  'bed',
#  'i',
#  'double',
#  'bed',
#  'single',
#  'zip',
#  'together',
#  'poorly',
#  'uncomfortably',
#  'so',
#  'cheap',
#  'such',
#  'bad',
#  'sleep',
#  'mouse',
#  'scurry',
#  'property',
#  'full',
#  'view',
#  'customer',
#  'main',
#  'lobby',
#  'din',
#  'bar',
#  'area',
#  'room',
#  'i',
#  'mouse',
#  'occasion',
#  'room',
#  'much',
#  'wear',
#  'wall',
#  'visibly',
#  'mark',
#  'damage',
#  'toilet',
#  'show',
#  'shower',
#  'totally',
#  'careless',
#  'i',
#  'non',
#  'smoke',
#  'room',
#  'room',
#  'i',
#  'reek',
#  'smoke',
#  'everywhere',
#  'curtain',
#  'toilet',
#  'bad',
#  'i',
#  'full',
#  'refund',
#  'lift',
#  'badly',
#  'adjust',
#  'dangerous',
#  'gap',
#  'lead',
#  'edge',
#  'og',
#  'car',
#  'door',
#  'park',
#  'horrible',
#  'park',
#  'garage',
#  'narrow',
#  'drive',
#  'full',
#  'entrance',
#  'garage',
#  'member',
#  'staff',
#  'inform',
#  'anyone',
#  'least',
#  'car',
#  'u',
#  'drive',
#  'back',
#  'then',
#  'i',
#  'ask',
#  'else',
#  'area',
#  'tell',
#  'side',
#  'street',
#  'park',
#  'then',
#  'park',
#  'resident',
#  'minute',
#  'park',
#  'circus',
#  'garage',
#  'minute',
#  'walk',
#  'away',
#  'garage',
#  'mention',
#  'maximum',
#  'duration',
#  'park',
#  'hotel',
#  'furnish',
#  'little',
#  'carpet',
#  'stair',
#  'instance',
#  'quite',
#  'wear',
#  'wifi',
#  'work',
#  'there',
#  'card',
#  'room',
#  'detail',
#  'network',
#  'phone',
#  'room',
#  'nice',
#  'clean',
#  'beware',
#  'shower',
#  'water',
#  'pressure',
#  'good',
#  'screen',
#  'front',
#  'bath',
#  'fairly',
#  'small',
#  'twist',
#  'shower',
#  'head',
#  'wall',
#  'inch',
#  'whole',
#  'bathroom',
#  'get',
#  'head',
#  'wall',
#  'people',
#  'able',
#  'stand',
#  'squat',
#  'little',
#  'i',
#  'full',
#  'price',
#  'hotel',
#  'frankly',
#  'i',
#  'star',
#  'hotel',
#  'london',
#  'i',
#  'hotel',
#  'star',
#  'base',
#  'room',
#  'comfort',
#  'staff',
#  'park',
#  'part',
#  'horrendous',
#  'start',
#  'finish',
#  'arrive',
#  'socket',
#  'work',
#  'phone',
#  'head',
#  'room',
#  'dirty',
#  'i',
#  'morning',
#  'bathroom',
#  'flood',
#  'water',
#  'way',
#  'room',
#  'wet',
#  'bag',
#  'shoe',
#  'toiletry',
#  'bag',
#  'etc',
#  'reception',
#  'phone',
#  'age',
#  'nobody',
#  'come',
#  'clean',
#  'mess',
#  'gm',
#  'breakfast',
#  'awful',
#  'dry',
#  'toast',
#  'eat',
#  'place',
#  'dirty',
#  'needle',
#  'process',
#  'full',
#  'refund',
#  'hotel',
#  'nothing',
#  'bathroom',
#  'standard',
#  'everything',
#  'bathroom',
#  'work',
#  'perfectly',
#  'phone',
#  'work',
#  'room',
#  'steam',
#  'room',
#  'action',
#  'sandwich',
#  'day',
#  'body',
#  'massage',
#  'spa',
#  'i',
#  'mention',
#  'concern',
#  'staff',
#  'management',
#  'bother',
#  'issue',
#  'solution',
#  'i',
#  'management',
#  'staff',
#  'guest',
#  'facility',
#  'nothing',
#  'great',
#  'hotel',
#  'tire',
#  'overprice',
#  'complete',
#  'renovation',
#  'poor',
#  'thin',
#  'mattress',
#  'single',
#  'push',
#  'together',
#  'double',
#  'room',
#  'i',
#  'especially',
#  'en',
#  'suite',
#  'bathroom',
#  'however',
#  'pizzeria',
#  'hotel',
#  'serve',
#  'poor',
#  'food',
#  'indian',
#  'retaurant',
#  'hotel',
#  'deceent',
#  'food',
#  'wifi',
#  'free',
#  'bite',
#  'early',
#  'fire',
#  'alarm',
#  'anything',
#  'wasnt',
#  'sure',
#  'time',
#  'back',
#  'swim',
#  'alarm',
#  'stay',
#  'room',
#  'also',
#  'swim',
#  'noe',
#  'tell',
#  'sign',
#  'something',
#  'reception',
#  'shld',
#  'tell',
#  'check',
#  'swim',
#  'time',
#  'staff',
#  'poker',
#  'smile',
#  'ask',
#  'guest',
#  'need',
#  'help',
#  'want',
#  'pay',
#  'advance',
#  'breakfast',
#  'open',
#  'account',
#  'expensive',
#  'room',
#  'also',
#  'good',
#  'morning',
#  'good',
#  'even',
#  'guest',
#  'good',
#  'manner',
#  'gentleman',
#  'everything',
#  'life',
#  'money',
#  'wifi',
#  'room',
#  'window',
#  'extra',
#  'charge',
#  'pound',
#  'day',
#  'company',
#  'operate',
#  'instead',
#  'min',
#  'entirely',
#  'definitely',
#  'guest',
#  'negativeno',
#  'negative',
#  'toilet',
#  'bathroom',
#  'generally',
#  'ability',
#  'tightly',
#  'close',
#  'window',
#  'therefore',
#  'cold',
#  'night',
#  'also',
#  'guest',
#  'next',
#  'door',
#  'pretty',
#  'loud',
#  'hotel',
#  'staff',
#  'little',
#  'sad',
#  'need',
#  'bite',
#  'update',
#  'spruce',
#  'lovely',
#  'pool',
#  'whole',
#  'area',
#  'clean',
#  'lick',
#  'room',
#  'look',
#  'picture',
#  'i',
#  'change',
#  'room',
#  'first',
#  'i',
#  'book',
#  'single',
#  'however',
#  'bed',
#  'armlength',
#  'closet',
#  'door',
#  'break',
#  'whn',
#  'i',
#  'receptionist',
#  'room',
#  'picture',
#  'display',
#  'book',
#  'com',
#  'i',
#  'room',
#  'exist',
#  'staff',
#  'friendly',
#  'enough',
#  'u',
#  'different',
#  'room',
#  'furnish',
#  'really',
#  'i',
#  'shock',
#  'star',
#  'hotel',
#  'there',
#  'air',
#  'condition',
#  'room',
#  'c',
#  'outside',
#  'roomtemperature',
#  'c',
#  'turn',
#  'air',
#  'ventilation',
#  'vain',
#  'also',
#  'incredibly',
#  'angle',
#  'tv',
#  'bite',
#  'annoy',
#  'face',
#  'away',
#  'i',
#  'bathroom',
#  'floor',
#  'quite',
#  'slippy',
#  'nearly',
#  'slip',
#  'room',
#  'air',
#  'con',
#  'justice',
#  'due',
#  'old',
#  'fashion',
#  'theme',
#  'hotel',
#  'i',
#  'probably',
#  'air',
#  'con',
#  'possibly',
#  'bite',
#  'armchair',
#  'comfortable',
#  'huge',
#  'rip',
#  'back',
#  'i',
#  'bite',
#  'crude',
#  'location',
#  'amount',
#  'visitor',
#  'room',
#  'first',
#  'floor',
#  'air',
#  'condition',
#  'room',
#  'unbearably',
#  'hot',
#  'breakfast',
#  'poor',
#  'walk',
#  'access',
#  'train',
#  'station',
#  'convolute',
#  'build',
#  'work',
#  'build',
#  'new',
#  'infraestructure',
#  'room',
#  'old',
#  'fashion',
#  'water',
#  'complimentry',
#  'tray',
#  'tea',
#  'coffee',
#  'there',
#  'fridge',
#  'carpet',
#  'old',
#  'smelly',
#  'available',
#  'room',
#  'free',
#  'park',
#  'breakfast',
#  'show',
#  'table',
#  'offer',
#  'tea',
#  'coffee',
#  'table',
#  'filthy',
#  'standard',
#  'food',
#  'appal',
#  'mouthful',
#  'person',
#  'check',
#  'guest',
#  'work',
#  'back',
#  'office',
#  'not',
#  'stay',
#  'interest',
#  'customer',
#  'future',
#  'business',
#  'doe',
#  'group',
#  'hotel',
#  'tire',
#  'class',
#  'room',
#  'ver',
#  'hot',
#  'airconditon',
#  'window',
#  'room',
#  'staff',
#  'bare',
#  'minimum',
#  'helpfulness',
#  'desire',
#  'value',
#  'extra',
#  'mile',
#  'room',
#  'mostly',
#  'clean',
#  'glass',
#  'bathroom',
#  'dusty',
#  'bathroom',
#  'old',
#  'dirty',
#  'date',
#  'basin',
#  'work',
#  'shower',
#  'incorporate',
#  'bath',
#  'work',
#  'well',
#  'breakfast',
#  'awful',
#  'coffee',
#  'taste',
#  'bad',
#  'bacon',
#  'little',
#  'choice',
#  'continental',
#  'option',
#  'little',
#  'food',
#  'look',
#  'unappealing',
#  'stale',
#  'cutlery',
#  'plate',
#  'cup',
#  'dirty',
#  'greasy',
#  'i',
#  'eat',
#  'felt',
#  'outside',
#  'hotel',
#  'night',
#  'park',
#  'full',
#  'park',
#  'nearby',
#  'quick',
#  'call',
#  'reception',
#  'advise',
#  'unhelpful',
#  'advise',
#  'unsafe',
#  'park',
#  'anywhere',
#  'else',
#  'hotel',
#  'park',
#  'secure',
#  'access',
#  'park',
#  'level',
#  'hotel',
#  'pedestrian',
#  'walk',
#  'way',
#  'car',
#  'risky',
#  'tad',
#  'inconvenient',
#  'comfy',
#  'try',
#  'charge',
#  'u',
#  'night',
#  'upgrade',
#  'room',
#  'window',
#  'room',
#  'anyway',
#  'book',
#  'double',
#  'room',
#  'twin',
#  'room',
#  'push',
#  'together',
#  'complain',
#  'change',
#  'room',
#  'double',
#  'room',
#  'date',
#  'old',
#  'cumbersome',
#  'check',
#  'process',
#  'poor',
#  'wifi',
#  'connectivity',
#  'quality',
#  'breakfast',
#  'better',
#  'separate',
#  'breakfast',
#  'room',
#  'point',
#  'large',
#  'group',
#  'travel',
#  'child',
#  'breakfast',
#  'rubbish',
#  'restaurant',
#  'canteen',
#  'room',
#  'shabby',
#  'wear',
#  'carpet',
#  'furniture',
#  'bed',
#  'uncomfortable',
#  'breakfast',
#  'disorganise',
#  'quality',
#  'large',
#  'city',
#  'hotel',
#  'really',
#  'usable',
#  'due',
#  'day',
#  'extra',
#  'hotel',
#  'facility',
#  'eg',
#  'pool',
#  'extremely',
#  'disappoint',
#  'free',
#  'internet',
#  'room',
#  'pay',
#  'device',
#  'connect',
#  'day',
#  'breakfast',
#  'buffet',
#  'good',
#  'example',
#  'yogurt',
#  'consistency',
#  'water',
#  'room',
#  'crack',
#  'yellow',
#  'water',
#  'drywall',
#  'plaster',
#  'ceiling',
#  'sink',
#  'c',
#  'somewhat',
#  'vent',
#  'almost',
#  'plug',
#  'dust',
#  'staff',
#  'definitely',
#  'friendly',
#  'job',
#  'adequately',
#  'likely',
#  'particularly',
#  'i',
#  'many',
#  'year',
#  'cleaner',
#  'nicer',
#  'way',
#  'way',
#  'better',
#  'value',
#  'star',
#  'hotel',
#  'experience',
#  'arrive',
#  'mindset',
#  'place',
#  'eat',
#  'internet',
#  ...]

# %%
# 긍정어사전, 부정어 사전에 없는 단어들만 저장
pos_new = []
neg_new = []
for p in range(len(filtered_list_pos)):
    if filtered_list_pos[p] not in pos_temp:
        if filtered_list_pos[p] not in neg_temp:
            pos_new.append(filtered_list_pos[p])

for n in range(len(filtered_list_neg)):
    if filtered_list_neg[n] not in pos_temp:
        if filtered_list_neg[n] not in neg_temp:
            neg_new.append(filtered_list_neg[n])

# %%
# 빈도 수 중 상위 50개 필터링

fd_pos = FreqDist(pos_new)
fd_pos=fd_pos.most_common(50)
fd_pos = dict(fd_pos)
fd_neg = FreqDist(neg_new)
fd_neg=fd_neg.most_common(50)
fd_neg = dict(fd_neg)

# %%
fd_pos
# Out:
# {'room': 1451,
#  'location': 1323,
#  'staff': 822,
#  'hotel': 640,
#  'i': 498,
#  'view': 390,
#  'canary': 313,
#  'wharf': 276,
#  'price': 268,
#  'breakfast': 241,
#  'value': 226,
#  'bed': 202,
#  'close': 175,
#  'restaurant': 167,
#  'upgrade': 165,
#  'area': 157,
#  'money': 151,
#  'service': 151,
#  'nothing': 149,
#  'size': 148,
#  'really': 144,
#  'very': 139,
#  'bar': 137,
#  'food': 136,
#  'window': 130,
#  'stay': 129,
#  'facility': 124,
#  'tube': 121,
#  'london': 115,
#  'station': 113,
#  'reception': 110,
#  'everything': 106,
#  'big': 105,
#  'book': 105,
#  'walk': 94,
#  'night': 89,
#  'bathroom': 89,
#  'positiveno': 88,
#  'place': 84,
#  'large': 78,
#  'also': 75,
#  'check': 73,
#  'pool': 69,
#  'even': 68,
#  'time': 67,
#  'minute': 65,
#  'day': 62,
#  'little': 62,
#  'u': 61,
#  'look': 55}

# %%
fd_neg # positive review에서 나타난 단어들의 빈도 수
# Out:
# {'room': 2528,
#  'i': 1686,
#  'hotel': 1156,
#  'staff': 758,
#  'breakfast': 628,
#  'window': 470,
#  'bed': 448,
#  'night': 372,
#  'old': 366,
#  'wifi': 340,
#  'date': 305,
#  'time': 301,
#  'book': 294,
#  'pay': 291,
#  'tire': 276,
#  'bite': 267,
#  'service': 267,
#  'air': 265,
#  'bathroom': 259,
#  'reception': 250,
#  'even': 239,
#  'day': 238,
#  'park': 230,
#  'also': 223,
#  'price': 210,
#  'nothing': 206,
#  'look': 200,
#  'little': 198,
#  'really': 195,
#  'food': 194,
#  'charge': 190,
#  'open': 189,
#  'shower': 189,
#  'very': 186,
#  'need': 182,
#  'decor': 178,
#  'stay': 178,
#  'pool': 173,
#  'door': 172,
#  'use': 169,
#  'water': 169,
#  'check': 167,
#  'carpet': 165,
#  'double': 163,
#  'restaurant': 161,
#  'u': 159,
#  'floor': 157,
#  'facility': 154,
#  'area': 152,
#  'sleep': 147}

# %%
# 필터링한 데이터를 csv 파일로 각각 저장
posi=pd.DataFrame()
posi['keyword']=fd_pos.keys()
posi['num']=fd_pos.values()
posi.sort_values(by='num',ascending=False,inplace=True)
posi.to_csv('pos.csv')

nega=pd.DataFrame()
nega['keyword']=fd_neg.keys()
nega['num']=fd_neg.values()
nega.sort_values(by='num',ascending=False,inplace=True)
nega.to_csv('neg.csv')

# %%
# negative review에서 많이 나타난 50개의 단어의 빈도수 출력
plt.figure(figsize=(15,5))
plt.xticks(rotation=90)
plt.title('NEGATIVE REVIEW')
plt.plot(nega['keyword'], nega['num'])

# %%
# negative review에서 많이 나타난 50개의 단어의 빈도수 출력
plt.figure(figsize=(15,5))
plt.xticks(rotation=90)
plt.title('POSITIVE REVIEW')
plt.plot(posi['keyword'], posi['num'])

# %%
# positive review와 negative review에서 겹치는 단어 수집
overlap = {}
j = 0
for i in range(len(posi['keyword'])):
    if i in nega['keyword']:
        temp = []
        temp.append(posi['num'][i])
        temp.append(nega['num'][i])
        overlap[posi['keyword'][i]] = temp[0]

# %%
overlap
# Out:
# {'room': 1451,
#  'location': 1323,
#  'staff': 822,
#  'hotel': 640,
#  'i': 498,
#  'view': 390,
#  'canary': 313,
#  'wharf': 276,
#  'price': 268,
#  'breakfast': 241,
#  'value': 226,
#  'bed': 202,
#  'close': 175,
#  'restaurant': 167,
#  'upgrade': 165,
#  'area': 157,
#  'money': 151,
#  'service': 151,
#  'nothing': 149,
#  'size': 148,
#  'really': 144,
#  'very': 139,
#  'bar': 137,
#  'food': 136,
#  'window': 130,
#  'stay': 129,
#  'facility': 124,
#  'tube': 121,
#  'london': 115,
#  'station': 113,
#  'reception': 110,
#  'everything': 106,
#  'big': 105,
#  'book': 105,
#  'walk': 94,
#  'night': 89,
#  'bathroom': 89,
#  'positiveno': 88,
#  'place': 84,
#  'large': 78,
#  'also': 75,
#  'check': 73,
#  'pool': 69,
#  'even': 68,
#  'time': 67,
#  'minute': 65,
#  'day': 62,
#  'little': 62,
#  'u': 61,
#  'look': 55}
